# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="150" height="200"/></a>
# <pre>
# <center><b><h2> Python for Data Science - 2305CS303 </b></center>
# <center><b><h2>Lab - 4</b></center>
# <left><b><h3>Roll No. :101 </b></left>
# <left><b><h3>Name : Bhojani Aastha</b></left>
# <pre>

# %% [markdown]
# ### 1) Character Category Counter
# **Problem:** Count uppercase, lowercase, digits, and special characters in a string.
#
# **Sample Inputs & Outputs:**
# - Input: `Python3@Lab` → Uppercase: 2, Lowercase: 7, Digits: 1, Special: 1
# - Input: `HELLO123` → Uppercase: 5, Lowercase: 0, Digits: 3, Special: 0
# - Input: `hi@#9` → Uppercase: 0, Lowercase: 2, Digits: 1, Special: 2

# %%
s=input("enter string")
upper=0
lower=0
digit=0
special=0
for ch in s:
    if ch.isupper():
        upper+=1
    elif ch.islower():
        lower+=1
    elif ch.isdigit():
        digit+=1
    else:
        special+=1
print("Uppercase:", upper)
print("Lowercase:", lower)
print("Digits:", digit)
print("Special:", special)
# Out:
# enter string Python3@Lab
# Uppercase: 2
# Lowercase: 7
# Digits: 1
# Special: 1

# %% [markdown]
# ### 2) Reverse Each Word
# - Input: `Python is Easy` → `nohtyP si ysaE`
# - Input: `Hello World` → `olleH dlroW`
# - Input: `Learn Python Fast` → `nraeL nohtyP tsaF`

# %%
str1 = input("Enter String : ")
str2 = " ".join(i[::-1] for i in str1.split(" ")) 
str2
# Out:
# Enter String :  Python is Easy
# 'nohtyP si ysaE'

# %% [markdown]
# ### 3) Case Pattern Identifier
# - `PYTHON` → Uppercase
# - `python` → Lowercase
# - `Python Programming` → Title Case

# %%
str1 = input("Enter String : ")
if str1.isupper():
    print(str1 ," -> Uppercase")
elif str1.islower():
    print(str1," -> Lowercase")
else:
    print(str1," -> Title Case")
# Out:
# Enter String :  PYTHON
# PYTHON  -> Uppercase

# %% [markdown]
# ### 4) First and Last Occurrence Finder
# - `programming`, `g` → First:3 Last:10
# - `banana`, `a` → First:1 Last:5
# - `hello`, `z` → Not found

# %%
str1 = "programming"
print("First : ",str1.find('g'),"Last : ",str1.rfind('g'))
str1 = "banana"
print("First : ",str1.find('a'),"Last : ",str1.rfind('a'))
str1 = "hello"
print("First : ",str1.find('z'),"Last : ",str1.rfind('z'))
# Out:
# First :  3 Last :  10
# First :  1 Last :  5
# First :  -1 Last :  -1

# %% [markdown]
# ### 5) Word Frequency Counter (ignore the case)
# - `Python is easy and Python is powerful` → python: 2
# - `Java is popular but java is verbose` → java: 2
# - `C is fast` → c:1

# %%
str1 = "Python is easy and Python is powerful"
s = "python"
str1=str1.split(" ")
c=0
for i in str1:
    if(s==i.lower()):
        c+=1
c
# Out:
# 2

# %% [markdown]
# ### 6) Remove Extra Spaces
# - `  Python   is   fun  ` → `Python is fun`
# - `   Hello   World ` → `Hello World`
# - `NoExtraSpace` → `NoExtraSpace`

# %%
str1=" Python   is   fun "
str1=str1.split()
str1
s=""
for i in str1:
    s+=(i+" ")
s=s.strip()
s
# Out:
# 'Python is fun'

# %% [markdown]
# ### 7) Prefix and Suffix Removal
# - `unhappy.txt` → `happy`
# - `pretest.py` → `test`
# - `unwanted.doc` → `wanted`

# %%
str1="unhappy.txt"
str1=str1.removeprefix("un")
str1=str1.removesuffix(".txt")
str1
# Out:
# 'happy'

# %% [markdown]
# ### 8) Replace Vowels
# - `Programming` → `Pr*gr*mm*ng`
# - `Education` → `*d*c*t**n`
# - `Sky` → `Sky`

# %%
str1="Programming"
s=""
for i in str1:
    if(i=='a' or i=='e' or i=='i' or i=='o' or i=='u'):
        i="*"
    s+=i
s
# Out:
# 'Pr*gr*mm*ng'

# %% [markdown]
# ### 9) String Compression
# - `aaabbcccc` → `a3b2c4`
# - `xxxyyyz` → `x3y3z1`
# - `abcd` → `a1b1c1d1`

# %%
str1="aaabbcccc"
s=""
for i in str1:
    cnt=str(str1.count(i))
    s+=cnt  

set(str1)
set(s)
# Out:
# 333224444

# %% [markdown]
# ### 10) Toggle Case (without using str.swapcase())
# - `PyThOn` → `pYtHoN`
# - `HELlo` → `helLO`
# - `Python` → `pYTHON`

# %%
str1 = "PyThOn"
s=""
for i in str1:
    if(i.islower()):
        s+=i.upper()
    elif i.isupper() :
        s+=i.lower()
    
s
# Out:
# 'pYtHoN'

# %% [markdown]
# ### 11) Username Validation
# #### valid username rules:
# 1. only alphabets and digits
# 2. does not start with a digit
# 3. length ≥ 6
#
# - `User123` → Valid
# - `123User` → Invalid
# - `Us@12` → Invalid

# %% [markdown]
# ### 12) Palindrome Checker (ignore the case)
# - `Madam` → Palindrome
# - `Level` → Palindrome
# - `Python` → Not Palindrome

# %%
name = "Madam"
name=name.lower()
if name == name[::-1]:
 print("Palindrom")
else:
 print("not palindrom")
# Out:
# Palindrom

# %% [markdown]
# ### 13) Longest Word Finder
# - `Python programming is interesting` → programming
# - `I love coding` → coding
# - `Data structures and algorithms` → structures

# %%
s="Python programming is interesting"
words=s.split()
res=""
for word in words:
    if len(word)>len(res):
        res=word
res
# Out:
# 'programming'

# %% [markdown]
# ### 14) Case Conversion
# - `python programming`
#   - Upper: PYTHON PROGRAMMING
#   - Lower: python programming
#   - Title: Python Programming
#   - Capitalize: Python programming

# %%
s1 = "python programming"
print(s1.upper())
print(s1.lower())
print(s1.title())
print(s1.capitalize())
# Out:
# PYTHON PROGRAMMING
# python programming
# Python Programming
# Python programming

# %% [markdown]
# ### 15) Custom Split
# - `apple,banana,grape`
# - `10|20|30`
# - `A-B-C-D`

# %%
marks = "A, B, C, D"
li = marks.split(", ")
marks = "-".join(li)
print(marks)
# Out:
# A-B-C-D
